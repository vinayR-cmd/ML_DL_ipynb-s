# %%
import pandas as pd
dataset=pd.read_csv("/content/Loan payments data.csv")
dataset
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  past_due_days  age             education  \
# ...

# %%
dataset.shape
# Out:
# (500, 11)

# %%
dataset.isnull().sum()
# Out:
# Loan_ID             0
# loan_status         0
# Principal           0
# terms               0
# effective_date      0
# due_date            0
# paid_off_time     100
# past_due_days     300
# age                 0
# education           0
# Gender              0
# dtype: int64

# %%
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# Loan_ID            0.0
# loan_status        0.0
# Principal          0.0
# terms              0.0
# effective_date     0.0
# due_date           0.0
# paid_off_time     20.0
# past_due_days     60.0
# age                0.0
# education          0.0
# Gender             0.0
# dtype: float64

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# np.float64(7.2727272727272725)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.drop(columns=['past_due_days'],inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Loan_ID             0
# loan_status         0
# Principal           0
# terms               0
# effective_date      0
# due_date            0
# paid_off_time     100
# age                 0
# education           0
# Gender              0
# dtype: int64

# %%
dataset.dropna(inplace=True)
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.shape
# Out:
# (400, 10)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 400 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Loan_ID         400 non-null    object
#  1   loan_status     400 non-null    object
#  2   Principal       400 non-null    int64
#  3   terms           400 non-null    int64
#  4   effective_date  400 non-null    object
#  5   due_date        400 non-null    object
#  6   paid_off_time   400 non-null    object
#  7   age             400 non-null    int64
#  8   education       400 non-null    object
#  9   Gender          400 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 34.4+ KB

# %%
for i in dataset.select_dtypes(include='object').columns:
  print(i)
  dataset[i].fillna(dataset[i].mode()[0],inplace=True)
# Out:
# Loan_ID
# loan_status
# effective_date
# due_date
# paid_off_time
# education
# Gender
# /tmp/ipython-input-4222886860.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset[i].fillna(dataset[i].mode()[0],inplace=True)

# %%
dataset
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  age             education  Gender
# ...

# %%
dataset.isnull().sum()
# Out:
# Loan_ID           0
# loan_status       0
# Principal         0
# terms             0
# effective_date    0
# due_date          0
# paid_off_time     0
# age               0
# education         0
# Gender            0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 400 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Loan_ID         400 non-null    object
#  1   loan_status     400 non-null    object
#  2   Principal       400 non-null    int64
#  3   terms           400 non-null    int64
#  4   effective_date  400 non-null    object
#  5   due_date        400 non-null    object
#  6   paid_off_time   400 non-null    object
#  7   age             400 non-null    int64
#  8   education       400 non-null    object
#  9   Gender          400 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 50.5+ KB

# %%
dataset.select_dtypes(include='int64').columns
# Out:
# Index(['Principal', 'terms', 'age'], dtype='object')

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='mean')
ar=imputer.fit_transform(dataset.select_dtypes(include='int64'))
ar
# Out:
# array([[1000.,   30.,   45.],
#        [1000.,   30.,   50.],
#        [1000.,   30.,   33.],
#        ...,
#        [ 800.,   15.,   30.],
#        [1000.,   30.,   38.],
#        [1000.,   30.,   28.]])

# %%
new_dataset=pd.DataFrame(ar,columns=dataset.select_dtypes(include='int64').columns)
new_dataset
# Out:
#      Principal  terms   age
# 0       1000.0   30.0  45.0
# 1       1000.0   30.0  50.0
# 2       1000.0   30.0  33.0
# 3       1000.0   15.0  27.0
# 4       1000.0   30.0  28.0
# ..         ...    ...   ...
# 395     1000.0   30.0  28.0
# 396     1000.0   15.0  26.0
# 397      800.0   15.0  30.0
# 398     1000.0   30.0  38.0
# 399     1000.0   30.0  28.0
#
# [400 rows x 3 columns]

# %%
dataset['terms'].mean()
# Out:
# np.float64(22.5675)

# %%
dataset
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 495  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 496  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 497  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 498  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 499  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  age             education  Gender
# ...

# %%
dataset.isnull().sum()
# Out:
# Loan_ID           0
# loan_status       0
# Principal         0
# terms             0
# effective_date    0
# due_date          0
# paid_off_time     0
# age               0
# education         0
# Gender            0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 400 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Loan_ID         400 non-null    object
#  1   loan_status     400 non-null    object
#  2   Principal       400 non-null    int64
#  3   terms           400 non-null    int64
#  4   effective_date  400 non-null    object
#  5   due_date        400 non-null    object
#  6   paid_off_time   400 non-null    object
#  7   age             400 non-null    int64
#  8   education       400 non-null    object
#  9   Gender          400 non-null    object
# dtypes: int64(3), object(7)
# memory usage: 50.5+ KB

# %%
from sklearn.preprocessing import OneHotEncoder
encoder=OneHotEncoder()

# %%
encoded=encoder.fit_transform(dataset[['loan_status','Gender']])
encoded_df=pd.DataFrame(encoded.toarray(),columns=encoder.get_feature_names_out(['loan_status','Gender']))
df_encoded = pd.concat([dataset.reset_index(drop=True), encoded_df], axis=1)
print(df_encoded)
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 395  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 396  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 397  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 398  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 399  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  age             education  Gender  \
# ...

# %%
dataset=df_encoded

# %%
display(df_encoded)
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 395  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 396  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 397  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 398  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 399  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  age             education  Gender  \
# ...

# %%
dataset
# Out:
#          Loan_ID         loan_status  Principal  terms effective_date  \
# 0    xqd20166231             PAIDOFF       1000     30       9/8/2016
# 1    xqd20168902             PAIDOFF       1000     30       9/8/2016
# 2    xqd20160003             PAIDOFF       1000     30       9/8/2016
# 3    xqd20160004             PAIDOFF       1000     15       9/8/2016
# 4    xqd20160005             PAIDOFF       1000     30       9/9/2016
# ..           ...                 ...        ...    ...            ...
# 395  xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 396  xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016
# 397  xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016
# 398  xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016
# 399  xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016
#
#        due_date     paid_off_time  age             education  Gender  \
# ...

# %%
import pandas as pd

# %%
df=pd.DataFrame({"SIZE":['s','m','l','xl','s','m','xl' ,'m']})
df.head()
# Out:
#   SIZE
# 0    s
# 1    m
# 2    l
# 3   xl
# 4    s

# %%
ord_data=["s","m","l","xl"]

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder(categories=[ord_data])
df['SIZE']=oe.fit_transform(df[['SIZE']])
df.head()
# Out:
#    SIZE
# 0   0.0
# 1   1.0
# 2   2.0
# 3   3.0
# 4   0.0

# %%
df
# Out:
#    SIZE
# 0   0.0
# 1   1.0
# 2   2.0
# 3   3.0
# 4   0.0
# 5   1.0
# 6   3.0
# 7   1.0

# %%
dataset.describe()
# Out:
#          Principal       terms         age  loan_status_COLLECTION_PAIDOFF  \
# count   400.000000  400.000000  400.000000                      400.000000
# mean    940.500000   22.567500   31.242500                        0.250000
# std     121.641859    8.128384    6.100963                        0.433555
# min     300.000000    7.000000   19.000000                        0.000000
# 25%     975.000000   15.000000   27.000000                        0.000000
# 50%    1000.000000   30.000000   30.000000                        0.000000
# 75%    1000.000000   30.000000   35.000000                        0.250000
# max    1000.000000   30.000000   51.000000                        1.000000
#
#        loan_status_PAIDOFF  Gender_female  Gender_male
# count           400.000000     400.000000   400.000000
# mean              0.750000       0.167500     0.832500
# std               0.433555       0.373889     0.373889
# min               0.000000       0.000000     0.000000
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(x="terms",data=dataset)
plt.show()

# %%
sns.boxplot(x="age",data=dataset)
plt.show()

# %%
sns.distplot(dataset["age"])
plt.show()
# Out:
# /tmp/ipython-input-2153789862.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["age"])

# %%
q1=dataset['age'].quantile(0.25)
q3=dataset['age'].quantile(0.75)
iqr=q3-q1
print(q1)
print(q3)
print(iqr)
# Out:
# 27.0
# 35.0
# 8.0

# %%
min_range=q1-(1.5*iqr)
max_range=q3+(1.5*iqr)

# %%
dataset=dataset[(dataset['age']>=min_range) & (dataset['age']<=max_range)]
sns.boxplot(x="age",data=dataset)
plt.show()

# %%
z_score=(dataset['age']-dataset['age'].mean())/dataset['age'].std()
dataset=dataset[abs(z_score)<3]
sns.boxplot(x="age",data=dataset)
plt.show()
